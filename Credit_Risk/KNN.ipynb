# %%
from sklearn.neighbors import KNeighborsClassifier
import pickle 
from sklearn.metrics import accuracy_score, classification_report
from yellowbrick.classifier import ConfusionMatrix

# %%
with open("credit.pkl","rb") as f:
    X_credit_training, y_credit_training, X_credit_test, y_credit_test = pickle.load(f)

# %%
Knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p = 2)
Knn.fit(X_credit_training, y_credit_training)
# Out:
# KNeighborsClassifier()

# %%
predict = Knn.predict(X_credit_test)
predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(6517,))

# %%
y_credit_test
# Out:
# array([0, 0, 0, ..., 1, 0, 0], shape=(6517,))

# %%
accuracy_score(y_credit_test, predict)
# Out:
# 0.8988798526929569

# %%
cm = ConfusionMatrix(Knn)
cm.fit(X_credit_training, y_credit_training)
cm.score(X_credit_test, y_credit_test)
# Out:
# 0.8988798526929569

# %%
print(classification_report(y_credit_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      5179
#            1       0.85      0.62      0.71      1338
#
#     accuracy                           0.90      6517
#    macro avg       0.88      0.79      0.83      6517
# weighted avg       0.90      0.90      0.89      6517
